# %%
#-- Developer : Olusoji Ekunnrin
#-- Date : October 17 2020
#-- Subject : Python – DAT-5301 – BMsBA1
#-- Program Name : Text Adventure Game Development

"""
Docstring:

    Introduction:
    2 warriors, chosen from the best of the best, set out to discover the 8th 
    wonder of the world. Over the seven hills and across the seven seas, at 
    the port of September, the god of ember asked for one - one warrior to 
    stay for all.

    She was brave, you could convince her otherwise. She knew it was her time.
    Sarah dropped her double edged Samorai swords and tied her warrior ribbon 
    by the feet of the god of ember. 
    With an effervescent smile, she whispered to you, "Go, find the Legend. 
    May the 8th be with you".

"""

import sys
import time

a = 2
b = 0.2

print("     ###################################")
print("     #                                 #")
print("     #     Legend of the 8th Wonder    #")
print("     #                                 #")
print("     ###################################")

time.sleep(a)



def game_start(): 
    
    print("\nHello and welcome to my Adventure Game!!!\n")
    input('<Press any key to continue>\n')
    print("""What's your name contestant?""")
    contestant_name = input('Input contestant name: \n')    
    print(f"\nWelcome {contestant_name}!!!!\n")
    input('<Press any key to continue>\n')

game_start()
 
def round_1():
  
    print(f"""In your quest to find the elusive 8th wonder of the world, you 
    arrive at the port of September. The god of ember grants you passage,
    and you arrive at a crossroad. Would you turn left or right?\n""")
    time.sleep(a)
    
    answer = input("Where will you turn? left/right ").lower().strip()

    if answer == "left":
            answer == print("you encounter 100 enemy warriors. They overpower you. Sorry you lost. Game Over.\n")

    elif answer == "right":
            answer == print("you are granted passage to The Land of the Whispering Palms.")
            input("<Press enter to continue>\n")
            round_2()   
    else:
            print("invalid choice, please start again")
            input("<Press enter to continue>\n")
            round_1()
        
        
def round_2():
    print("""At the Land of the Whispering Palms, you meet the guardian monster who offers you\
    two pills. One you must take.""")

    answer = input("Which pill will you take? red/blue ").lower().strip()
    time.sleep(a)
    if answer == "red":
            answer == print("you encounter 100 alien warriors. Would you fight or run?")

            answer = input("Will you fight/run")

            if answer == "fight":
                    answer == input("Like a true warrior, you fought gallantly. However, they overpower you. Sorry you lost. Game Over.")
            elif answer == "run":
                    answer == input("You run straight into a pool of fire. Sorry you lost. Game Over.")

    elif answer == "blue":
            answer == print("You encounter a monster, would you run, hide or attack?.")

            answer = input("Will you run/hide/attack")

            if answer == "run":
                answer == input("Smart move, you made it away safely. The quest for the 8th wonder continues.")
                input("<Press enter to continue>\n")

                round_3()
            elif answer == "hide":
                answer == input("Wrong move. This monster isn't leaving. Sorry you lost. Game Over.\n")
            elif answer =="attack":
                answer == input ("You are no match for this monster. Sorry you lost. Game Over.\n")

    else:
            print("invalid choice, please start again\n")
            round_2()


def round_3():
    print("Welcome to the Land of the Living Dead, my name is Optimus and i will be your guide")
    time.sleep(a)
    print("I have been monitoring your quest, right from losing Sarah at the port of September,") 
    time.sleep(a)
    print("to making it through the land of the Whispering Palms. ") 
    time.sleep(a)
    print()      
    print("The treasure you seek, the Legend of the 8th Wonder lives here.")
    time.sleep(a)
    print()    
    print("Find it you must. Otherwise, here you die.")
    time.sleep(a)
    s = '"Now choose your path. Destiny awaits on the other side. May the 8th be with you."'
    for character in s:
        sys.stdout.write(character)
        time.sleep(b)
    time.sleep(a)
    print()
    print("Path #1: Open the red door.")
    print("Path #2: Open the green door.")
    print("Path #3: Open the blue door.")
    time.sleep(a)
    
    answer = input("Which door will you open? red/green/blue.")
    if answer == "red":
            time.sleep(a)
            answer == print('''\nYou meet erasmus who introduces himself as a messenger of the Oz,\
        the god of destiny. He is on a seven days trip to Redeplo on behalf of Oz. He says\
        he know about your quest and urges you to follow him on this trip before you continue.\
        Will you follow or continue on your quest?''')

            answer = input("Will you follow erasmus/continue on your quest")

            if answer == "follow erasmus":
                print()
                time.sleep(a)
                answer == input('''\nYou follow erasmus, not knowing he is Oz, the god of destiny in disguise.\
                Just at the entrance of Redeplo, he transforms into Oz and congratulates you for your\
                doggedness, confidence, grit, faith and patience. He unearths a box of treasure and hands\
                you the 8th wonder of the world. Now countdown with me.''')
                input("< Press ENTER to continue. >\n")
                count = 10

                while count > 0:
                    print(count)
                    count = count - 1
                    input("< Press ENTER to continue. >\n")
                print("CONGRATULATIONS. YOU WIN.")
            elif answer == "continue on your quest":
                answer == input("Wrong move. Sorry you lost. Game Over.")
            else:
                fail()

    elif answer == "green":
            answer == print("You encounter a monster, would you run, hide or attack?.")

            answer = input("Will you run/hide/attack")

            if answer == "run":
                answer == input("Wrong move. This monster is faster than you. Sorry you lost. Game Over.")
            elif answer == "hide":
                answer == input("Wrong move. This monster isn't leaving. Sorry you lost. Game Over.\n")
            elif answer =="attack":
                answer == input ("You are no match for this monster. Sorry you lost. Game Over.\n")

    else:
        fail()

        
def fail():
    print("You've failed, but thanks for playing!")
    input('<Press any key to exit>\n')
        
round_1()
# Out:
#      ###################################
#      #                                 #
#      #     Legend of the 8th Wonder    #
#      #                                 #
#      ###################################
#
# Hello and welcome to my Adventure Game!!!
